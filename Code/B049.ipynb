# %%
	
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.modeling import models, fitting
fitter = fitting.LinearLSQFitter()
from scipy.ndimage import median_filter
from tqdm import tqdm
from random import gauss
from scipy.interpolate import interp1d

# %%
Aug2005='../Spectra/B049/FEROS_2005AUG/ADP.2016-09-21T09:18:13.271.fits'
Sept2005='../Spectra/B049/FEROS_2005SEP/ADP.2016-09-21T09:18:32.411.fits'
Aug2013='../Spectra/B049/FEROS_2013AUG/ADP.2016-09-27T09:50:45.369.fits'
fits.getheader(Aug2013)
# Out:
# SIMPLE  =                    T / Written by IDL:  Mon Sep 26 20:04:33 2016
# BITPIX  =                    8
# NAXIS   =                    0
# EXTEND  =                    T / File contains extensions
# DATASUM = '         0'         / data unit checksum updated 2016-09-26T20:04:34
# ORIGIN  = 'ESO-LASILLA'        / Origin
# FILENAME= 'f06911.bdf'         / Original file base-name
# OBJECT  = 'smc-cep-1365'       / Object
# RA      =            12.422698 / [deg] Right ascension
# DEC     =            -73.23954 / [deg] Declination
# EQUINOX =               2000.0 / Equinox
# DATE-OBS= '2013-08-11T07:12:41.497' / Start of observation
# MJD-OBS =       56515.30048029 / [d] Start of observation
# TM-START=       25961.49619315 / MIDAS desc.: O_TIME(5)
# EXPTIME =            1800.0055 / [s] Total integration time
# TELESCOP= 'MPG/ESO-2.2'        / Telescope
# INSTRUME= 'FEROS   '           / Instrument
# RADECSYS= 'FK5     '           / Reference frame
# OBSERVER= 'UNKNOWN '           / MIDAS desc.: OBSERVER(1)
# AIRMASS =             1.398076 / MIDAS desc.: O_AIRM(1)
# NLINES  =                   15
# UTC     =            25956.097 / 07:12:36.097 UTC at start (sec)
# LST     =               85759. / 23:49:18.000 LST at start (sec)
# PI-COI  = 'UNKNOWN '           / PI-COI name.
# EXPTYPE = 'SCIENCE '
# FOCOFF  =              473.282
# PIPEFILE= 'r.FEROS.2013-08-11T07:12:41.496.1101.fits'
# MEFFILE = 'r.FEROS.2013-08-11T07:12:41.496.1081.fits'
# HIERARCH ESO ADA GUID STATUS = 'OFF     ' / Status of autoguider
# HIERARCH ESO ADA POSANG = 0.9 / Position angle at start
# HIERARCH ESO DET BITS = 16 / Bits per pixel readout
# HIERARCH ESO DET CHIP1 DATE = '2003-10-03' / Date of installation [YYYY-MM-DD
# HIERARCH ESO DET CHIP1 ID = 'CCD-60  ' / Detector chip identification
# HIERARCH ESO DET CHIP1 INDEX = 1 / Chip index
# HIERARCH ESO DET CHIP1 NAME = 'EEV CCD-44' / Detector chip name
# HIERARCH ESO DET CHIP1 NX = 2048 / # of pixels along X
# HIERARCH ESO DET CHIP1 NY = 4096 / # of pixels along Y
# HIERARCH ESO DET CHIP1 PSZX = 15. / Size of pixel in X
# HIERARCH ESO DET CHIP1 PSZY = 15. / Size of pixel in Y
# HIERARCH ESO DET CHIP1 X = 1 / X location in array
# HIERARCH ESO DET CHIP1 XGAP = 0. / Gap between chips along x
# HIERARCH ESO DET CHIP1 Y = 1 / Y location in array
# HIERARCH ESO DET CHIP1 YGAP = 0. / Gap between chips along y
# HIERARCH ESO DET CHIPS = 1 / # of chips in detector array
# HIERARCH ESO DET DATE = '2003-10-03' / Installation date
# HIERARCH ESO DET DEC = 0. / Apparent 00:00:00.0 DEC at start
# HIERARCH ESO DET DID = 'ESO-VLT-DIC.CCDDCS,ESO-VLT-DIC.FCDDCS' / Diction
# HIERARCH ESO DET EXP NO = 1181 / Unique exposure ID number
# HIERARCH ESO DET EXP RDTTIME = 41.426 / image readout time
# HIERARCH ESO DET EXP TYPE = 'Normal  ' / Exposure type
# HIERARCH ESO DET EXP XFERTIM = 41.37 / image transfer time
# HIERARCH ESO DET FRAM ID = 1 / Image sequencial number
# HIERARCH ESO DET FRAM TYPE = 'Normal  ' / Type of frame
# HIERARCH ESO DET ID = 'CCD FIERA - Rev: 3.96' / Detector system Id
# HIERARCH ESO DET NAME = 'feros - FEROS' / Name of detector system
# HIERARCH ESO DET OUT1 CHIP = 1 / Chip to which the output belongs
# HIERARCH ESO DET OUT1 CONAD = 0. / Conversion from ADUs to electrons
# HIERARCH ESO DET OUT1 GAIN = 0. / Conversion from electrons to ADU
# HIERARCH ESO DET OUT1 ID = 'R       ' / Output ID as from manufacturer
# HIERARCH ESO DET OUT1 INDEX = 2 / Output index
# HIERARCH ESO DET OUT1 NAME = 'R       ' / Description of output
# HIERARCH ESO DET OUT1 NX = 2048 / valid pixels along X
# HIERARCH ESO DET OUT1 NY = 4096 / valid pixels along Y
# HIERARCH ESO DET OUT1 OVSCX = 50 / Overscan region in X
# HIERARCH ESO DET OUT1 OVSCY = 0 / Overscan region in Y
# HIERARCH ESO DET OUT1 PRSCX = 50 / Prescan region in X
# HIERARCH ESO DET OUT1 PRSCY = 0 / Prescan region in Y
# HIERARCH ESO DET OUT1 RON = 0. / Readout noise per output (e-)
# HIERARCH ESO DET OUT1 X = 2048 / X location of output
# HIERARCH ESO DET OUT1 Y = 1 / Y location of output
# HIERARCH ESO DET OUTPUTS = 1 / # of outputs
# HIERARCH ESO DET OUTREF = 0 / reference output
# HIERARCH ESO DET RA = 0. / Apparent 00:00:00.0 RA at start
# HIERARCH ESO DET READ CLOCK = 'R 225Kps Low Gain' / Readout clock pattern use
# HIERARCH ESO DET READ MODE = 'normal  ' / Readout method
# HIERARCH ESO DET READ NFRAM = 1 / Number of readouts buffered in sin
# HIERARCH ESO DET READ SPEED = 'Fast    ' / Readout speed
# HIERARCH ESO DET SHUT ID = 'Feros shutter' / Shutter unique identifier
# HIERARCH ESO DET SHUT TMCLOS = 0.075 / Time taken to close shutter
# HIERARCH ESO DET SHUT TMOPEN = 0.064 / Time taken to open shutter
# HIERARCH ESO DET SHUT TYPE = 'IRIS    ' / type of shutter
# HIERARCH ESO DET SOFW MODE = 'Normal  ' / CCD sw operational mode
# HIERARCH ESO DET WIN1 BINX = 1 / Binning factor along X
# HIERARCH ESO DET WIN1 BINY = 1 / Binning factor along Y
# HIERARCH ESO DET WIN1 DIT1 = 1800.005466 / actual subintegration time
# HIERARCH ESO DET WIN1 DKTM = 1800.0961 / Dark current time
# HIERARCH ESO DET WIN1 NDIT = 1 / # of subintegrations
# HIERARCH ESO DET WIN1 NX = 2148 / # of pixels along X
# HIERARCH ESO DET WIN1 NY = 4096 / # of pixels along Y
# HIERARCH ESO DET WIN1 ST = T / If T, window enabled
# HIERARCH ESO DET WIN1 STRX = 1 / Lower left pixel in X
# HIERARCH ESO DET WIN1 STRY = 1 / Lower left pixel in Y
# HIERARCH ESO DET WIN1 UIT1 = 1800. / user defined subintegration time
# HIERARCH ESO DET WINDOWS = 1 / # of windows readout
# HIERARCH ESO INS ADC1 DEC = -731421.39475 / Telescope desclination [deg].
# HIERARCH ESO INS ADC1 END = 9.6235 / Position angle at end [deg].
# HIERARCH ESO INS ADC1 MODE = 'OFF     ' / ADC mode.
# HIERARCH ESO INS ADC1 RA = 4941.823248 / Telescope right ascension [deg].
# HIERARCH ESO INS ADC2 DEC = -731421.39103 / Telescope desclination [deg].
# HIERARCH ESO INS ADC2 END = 9.5549 / Position angle at end [deg].
# HIERARCH ESO INS ADC2 MODE = 'OFF     ' / ADC mode.
# HIERARCH ESO INS ADC2 RA = 4941.823248 / Telescope right ascension [deg].
# HIERARCH ESO INS ADCA NAME = 'OUT     ' / ADC arm position name.
# HIERARCH ESO INS CALMIRR1 ID = 'PARK    ' / Sliding cal. sel. mirror unique ID
# HIERARCH ESO INS CALMIRR1 NAME = 'PARK    ' / Sliding cal. sel. mirror name.
# HIERARCH ESO INS CALMIRR1 NO = 1 / Sliding cal. sel. mirror number.
# HIERARCH ESO INS CALMIRR1 TYPE = 'FREE    ' / Sliding cal. sel. mirror element.
# HIERARCH ESO INS CALMIRR2 ID = 'LAMP3   ' / Rotating sel. mirror unique ID.
# HIERARCH ESO INS CALMIRR2 NAME = 'LAMP3   ' / Rotating sel. mirror name.
# HIERARCH ESO INS CALMIRR2 NO = 4 / Rotating sel. mirror number.
# HIERARCH ESO INS CALMIRR2 TYPE = 'LAMP    ' / Rotating sel. mirror element.
# HIERARCH ESO INS DATE = '2000-06-16' / Instrument release date (yyyy-mm-d
# HIERARCH ESO INS DID = 'ESO-VLT-DIC.FEROS_ICS-165245' / Data dictionary
# HIERARCH ESO INS FILT1 ENC = 1932 / Absolute position [Enc].
# HIERARCH ESO INS FILT1 POS = 0. / NDFW Position [density].
# HIERARCH ESO INS ID = 'FEROS/1.57' / Instrument ID.
# HIERARCH ESO INS MIRR3 NAME = 'FEROS   ' / FEROS-WFI sel.mirror name.
# HIERARCH ESO INS MODE = 'FEROS   ' / Instrument mode used.
# HIERARCH ESO INS PATH = 'DEFAULT ' / Optical path used.
# HIERARCH ESO INS SENS7 ID = 'HUMI    ' / sensor ID.
# HIERARCH ESO INS SENS7 MAX = 10.81 / Maximum value.
# HIERARCH ESO INS SENS7 MEAN = 10.732187 / Average value.
# HIERARCH ESO INS SENS7 MIN = 10.7 / Minimum value.
# HIERARCH ESO INS SENS7 NAME = 'Humidity' / sensor common name.
# HIERARCH ESO INS SENS7 VAL = 10.72 / Sensor numeric value.
# HIERARCH ESO INS SENS8 ID = 'LNLV    ' / sensor ID.
# HIERARCH ESO INS SENS8 NAME = 'LN2 level' / sensor common name.
# HIERARCH ESO INS SENS8 VAL = 54.58 / Sensor numeric value.
# HIERARCH ESO INS SHUT1 ID = 'DARK    ' / FCU shutter unique ID.
# HIERARCH ESO INS SHUT1 NAME = 'DARK    ' / FCU shutter name.
# HIERARCH ESO INS SHUT1 NO = 1 / FCU shutter number.
# HIERARCH ESO INS SHUT1 TYPE = 'FREE    ' / FCU shutter element.
# HIERARCH ESO INS SWSIM = 'NORMAL  ' / Software simulation.
# HIERARCH ESO INS TEMP1 ID = 'TEMP1   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP1 MAX = 14.1 / Maximum value [C].
# HIERARCH ESO INS TEMP1 MEAN = 14.099375 / Average value [C].
# HIERARCH ESO INS TEMP1 MIN = 14.09 / Minimum value [C].
# HIERARCH ESO INS TEMP1 NAME = 'Temperature 1' / Temperature sensor name.
# HIERARCH ESO INS TEMP1 VAL = 14.1 / Temperature sensor numeric value [
# HIERARCH ESO INS TEMP2 ID = 'TEMP2   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP2 MAX = 14.36 / Maximum value [C].
# HIERARCH ESO INS TEMP2 MEAN = 14.3575 / Average value [C].
# HIERARCH ESO INS TEMP2 MIN = 14.35 / Minimum value [C].
# HIERARCH ESO INS TEMP2 NAME = 'Temperature 2' / Temperature sensor name.
# HIERARCH ESO INS TEMP2 VAL = 14.35 / Temperature sensor numeric value [
# HIERARCH ESO INS TEMP3 ID = 'TEMP3   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP3 MAX = 14.38 / Maximum value [C].
# HIERARCH ESO INS TEMP3 MEAN = 14.368125 / Average value [C].
# HIERARCH ESO INS TEMP3 MIN = 14.36 / Minimum value [C].
# HIERARCH ESO INS TEMP3 NAME = 'Temperature 3' / Temperature sensor name.
# HIERARCH ESO INS TEMP3 VAL = 14.38 / Temperature sensor numeric value [
# HIERARCH ESO INS TEMP4 ID = 'TEMP4   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP4 MAX = 14.03 / Maximum value [C].
# HIERARCH ESO INS TEMP4 MEAN = 14.0275 / Average value [C].
# HIERARCH ESO INS TEMP4 MIN = 14.02 / Minimum value [C].
# HIERARCH ESO INS TEMP4 NAME = 'Temperature 4' / Temperature sensor name.
# HIERARCH ESO INS TEMP4 VAL = 14.05 / Temperature sensor numeric value [
# HIERARCH ESO INS TEMP5 ID = 'TEMP5   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP5 MAX = 13.94 / Maximum value [C].
# HIERARCH ESO INS TEMP5 MEAN = 13.930938 / Average value [C].
# HIERARCH ESO INS TEMP5 MIN = 13.92 / Minimum value [C].
# HIERARCH ESO INS TEMP5 NAME = 'Temperature 5' / Temperature sensor name.
# HIERARCH ESO INS TEMP5 VAL = 13.96 / Temperature sensor numeric value [
# HIERARCH ESO INS TEMP6 ID = 'TEMP6   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP6 MAX = 15.34 / Maximum value [C].
# HIERARCH ESO INS TEMP6 MEAN = 15.269063 / Average value [C].
# HIERARCH ESO INS TEMP6 MIN = 15.19 / Minimum value [C].
# HIERARCH ESO INS TEMP6 NAME = 'Temperature 6' / Temperature sensor name.
# HIERARCH ESO INS TEMP6 VAL = 15.25 / Temperature sensor numeric value [
# HIERARCH ESO OBS DID = 'ESO-VLT-DIC.OBS-1.11' / OBS Dictionary
# HIERARCH ESO OBS EXECTIME = 0 / Expected execution time
# HIERARCH ESO OBS GRP = '0       ' / linked blocks
# HIERARCH ESO OBS ID = 100340951 / Observation block ID
# HIERARCH ESO OBS NAME = 'smc-cep-1365' / OB name
# HIERARCH ESO OBS OBSERVER = 'UNKNOWN ' / Observer Name
# HIERARCH ESO OBS PI-COI ID = 0 / ESO internal PI-COI ID
# HIERARCH ESO OBS PI-COI NAME = 'UNKNOWN ' / PI-COI name
# HIERARCH ESO OBS PROG ID = '091.D-0414(B)' / ESO program identification
# HIERARCH ESO OBS START = '2013-08-11T07:02:48' / OB start time
# HIERARCH ESO OBS TARG NAME = 'smc-cep-1365' / OB target name
# HIERARCH ESO OBS TPLNO = 2 / Template number within OB
# HIERARCH ESO OCS DET1 IMGNAME = 'FEROS_ech_obs_objsky' / Data File Name.
# HIERARCH ESO OCS DET1 NAMING = 'Sequence-Naming' / Data File Naming Type.
# HIERARCH ESO TEL AG FIBSELEC = 'OBJFIB  ' / Fiber currently used (SKY or OBJ)
# HIERARCH ESO TEL AG FIBX = 0. / Fiber position X
# HIERARCH ESO TEL AG FIBY = 0. / Fiber position Y
# HIERARCH ESO TEL AG REFX = 822.2 / Autoguider reference pixel X
# HIERARCH ESO TEL AG REFY = 518.8 / Autoguider reference pixel Y
# HIERARCH ESO TEL AIRM END = 1.393 / Airmass at end
# HIERARCH ESO TEL AIRM START = 1.406 / Airmass at start
# HIERARCH ESO TEL ALT = 45.291 / Alt angle at start (deg)
# HIERARCH ESO TEL AMBI FWHM END = 0.86 / Observatory Seeing queried from AS
# HIERARCH ESO TEL AMBI FWHM START = 0.9 / Observatory Seeing queried
# HIERARCH ESO TEL AMBI PRES END = 770.9 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI PRES START = 770.8 / Observatory ambient air pr
# HIERARCH ESO TEL AMBI RHUM = 8. / Observatory ambient relative humi
# HIERARCH ESO TEL AMBI TEMP = 13.25 / Observatory ambient temperature qu
# HIERARCH ESO TEL AMBI WINDDIR = 204. / Observatory ambient wind directio
# HIERARCH ESO TEL AMBI WINDSP = 13.8 / Observatory ambient wind speed que
# HIERARCH ESO TEL AZ = 353.822 / Az angle at start (deg) S=0,W=90
# HIERARCH ESO TEL CHOP ST = F / True when chopping is active
# HIERARCH ESO TEL DATE = '2000-10-15T15:21:35.745' / TCS installation date
# HIERARCH ESO TEL DID = 'ESO-2P2-DIC.TCS-1.8' / Data dictionary for TEL
# HIERARCH ESO TEL DOME STATUS = 'FULLY-OPEN' / Dome status
# HIERARCH ESO TEL FOCU ID = 'CA      ' / Telescope focus station ID
# HIERARCH ESO TEL FOCU LEN = 8.009 / Focal length (m)
# HIERARCH ESO TEL FOCU SCALE = 11.65 / Focal scale (arcsec/mm)
# HIERARCH ESO TEL FOCU VALUE = 23481. / M2 setting (mm)
# HIERARCH ESO TEL GEOELEV = 2335. / Elevation above sea level (m)
# HIERARCH ESO TEL GEOLAT = -29.2543 / Tel geo latitute (+=North) (deg)
# HIERARCH ESO TEL GEOLON = -70.7346 / Tel geo longitute (+=East) (deg)
# HIERARCH ESO TEL HSS HUMI1 END = 13.71 / outside south of dome in shadow
# HIERARCH ESO TEL HSS HUMI1 START = 12.81 / outside south of dome in s
# HIERARCH ESO TEL HSS HUMI2 END = 12.98 / inside dome midheight
# HIERARCH ESO TEL HSS HUMI2 START = 12.93 / inside dome midheight
# HIERARCH ESO TEL ID = 'v 172600' / TCS version number
# HIERARCH ESO TEL MOON DEC = -5.7247 / -05:43:28.9 DEC (J2000) (deg)
# HIERARCH ESO TEL MOON DIST = 100.97887 / Moon distance to target
# HIERARCH ESO TEL MOON RA = 187.698493 / 12:30:47.6 RA (J2000) (deg)
# HIERARCH ESO TEL OPER = 'I: Condor' / Telescope Operator
# HIERARCH ESO TEL PARANG END = -9.409 / Parallactic angle at end (deg)
# HIERARCH ESO TEL PARANG START = -19.001 / Parallactic angle at start (deg)
# HIERARCH ESO TEL TARG ALPHA = 4940.951 / Alpha coordinate for the target
# HIERARCH ESO TEL TARG DELTA = -731407.008 / Delta coordinate for the target
# HIERARCH ESO TEL TARG EPOCH = 2000. / Epoch
# HIERARCH ESO TEL TARG EPOCHSYSTEM = 'J       ' / Epoch system (default J=Ju
# HIERARCH ESO TEL TARG EQUINOX = 2000. / Equinox
# HIERARCH ESO TEL TARG PMA = 0. / Proper Motion Alpha
# HIERARCH ESO TEL TARG PMD = 0. / Proper motion Delta
# HIERARCH ESO TEL TRAK RATEA = 15. / Tracking rate in RA (arcsec/sec)
# HIERARCH ESO TEL TRAK RATED = 0. / Tracking rate in DEC (arcsec/sec)
# HIERARCH ESO TEL TRAK STATUS = 'NORMAL  ' / Tracking status
# HIERARCH ESO TEL TSS TEMP1 END = 12.69 / air outside south of dome in shado
# HIERARCH ESO TEL TSS TEMP1 START = 12.98 / air outside south of dome
# HIERARCH ESO TEL TSS TEMP10 END = 9.83 / plate sensor looking into sky top
# HIERARCH ESO TEL TSS TEMP10 START = 9.7 / plate sensor looking into
# HIERARCH ESO TEL TSS TEMP11 END = 12.73 / air inside dome midheight
# HIERARCH ESO TEL TSS TEMP11 START = 12.95 / air inside dome midheight
# HIERARCH ESO TEL TSS TEMP12 END = 12.66 / air for instrument
# HIERARCH ESO TEL TSS TEMP12 START = 12.83 / air for instrument
# HIERARCH ESO TEL TSS TEMP13 END = 15.87 / surface delta hydrostatic pad
# HIERARCH ESO TEL TSS TEMP13 START = 15.85 / surface delta hydrostatic
# HIERARCH ESO TEL TSS TEMP14 END = 13.03 / air inside adapter
# HIERARCH ESO TEL TSS TEMP14 START = 12.71 / air inside adapter
# HIERARCH ESO TEL TSS TEMP2 END = 11.14 / air outside north of dome, road he
# HIERARCH ESO TEL TSS TEMP2 START = 11.38 / air outside north of dome,
# HIERARCH ESO TEL TSS TEMP3 END = 13.06 / air at low level in dome near floo
# HIERARCH ESO TEL TSS TEMP3 START = 13.13 / air at low level in dome n
# HIERARCH ESO TEL TSS TEMP4 END = 12.35 / surface of M1
# HIERARCH ESO TEL TSS TEMP4 START = 12.43 / surface of M1
# HIERARCH ESO TEL TSS TEMP5 END = 11.95 / air close to M1 surface
# HIERARCH ESO TEL TSS TEMP5 START = 11.8 / air close to M1 surface
# HIERARCH ESO TEL TSS TEMP6 END = 10. / surface midheight of lower Serruri
# HIERARCH ESO TEL TSS TEMP6 START = 9.88 / surface midheight of lower
# HIERARCH ESO TEL TSS TEMP7 END = 12.49 / surface midheight of upper Serruri
# HIERARCH ESO TEL TSS TEMP7 START = 12.41 / surface midheight of upper
# HIERARCH ESO TEL TSS TEMP8 END = 11.3 / surface on M2
# HIERARCH ESO TEL TSS TEMP8 START = 11.11 / surface on M2
# HIERARCH ESO TEL TSS TEMP9 END = 11.61 / air close to top ring
# HIERARCH ESO TEL TSS TEMP9 START = 11.63 / air close to top ring
# HIERARCH ESO TPL DID = 'ESO-VLT-DIC.TPL-1.9' / Data dictionary for TPL
# HIERARCH ESO TPL EXPNO = 1 / Exposure number within template
# HIERARCH ESO TPL ID = 'FEROS_ech_obs_objsky' / Template signature ID
# HIERARCH ESO TPL NAME = 'FEROS obs. object-sky' / Template name
# HIERARCH ESO TPL NEXP = 1 / Number of exposures within templat
# HIERARCH ESO TPL PRESEQ = 'FEROS_ech_obs_objsky.seq' / Sequencer script
# HIERARCH ESO TPL START = '2013-08-11T07:12:35' / TPL start time
# HIERARCH ESO TPL VERSION = '1.0     ' / Version of the template
# HIERARCH ESO PRO CATG = 'RED_SCI_1'
# HIERARCH ESO PRO TYPE = 'REDUCED_SOS'
# HIERARCH ESO PRO REC1 DRS ID = 'ESO-MIDAS/15SEPpl1.0'
# HIERARCH ESO PRO REC1 PIPE ID = 'fern/1.0.0'
# HIERARCH ESO DRS BARYCORR = -1.80304
# HIERARCH ESO PRO REC1 FIBRE NO = 1
# HIERARCH ESO PRO REC1 FIBRE NAME = 'OBJECT  '
# HIERARCH ESO PRO REC1 LOC_CUTSTEP = 10
# HIERARCH ESO PRO REC1 LOC_WINDOW = 25
# HIERARCH ESO PRO REC1 FIT_DEG = 5
# HIERARCH ESO PRO REC1 LOC_THRES = 0.9
# HIERARCH ESO PRO REC1 LOC_MODE = 'S       '
# HIERARCH ESO PRO REC1 LOC_METHOD = 'R       '
# HIERARCH ESO PRO REC1 BG_MODE = 'B       '
# HIERARCH ESO PRO REC1 BG_STEPX = 51
# HIERARCH ESO PRO REC1 BG_STEPY = 51
# HIERARCH ESO PRO REC1 BG_WIDTHX = 21
# HIERARCH ESO PRO REC1 BG_WIDTHY = 45
# HIERARCH ESO PRO REC1 BG_MEDIANX = 4
# HIERARCH ESO PRO REC1 BG_MEDIANY = 11
# HIERARCH ESO PRO REC1 BG_DIST = 50
# HIERARCH ESO PRO REC1 PROFILE_W = 15
# HIERARCH ESO PRO REC1 FIBER_OFF1 = -9
# HIERARCH ESO PRO REC1 FIBER_OFF2 = 9
# HIERARCH ESO PRO REC1 FIBER_MODE = 2
# HIERARCH ESO PRO REC1 IMG_WRITE = 'N       '
# HIERARCH ESO PRO REC1 SPECTR_TYPE = 'G       '
# HIERARCH ESO PRO REC1 EXT_MODE = 'S       '
# HIERARCH ESO PRO REC1 PROFILE_GET = 'N       '
# HIERARCH ESO PRO REC1 EXT_ITER = 3
# HIERARCH ESO PRO REC1 CCD_RON = 1.688
# HIERARCH ESO PRO REC1 CCD_GAIN = 2.962
# HIERARCH ESO PRO REC1 CCD_THRES = 4.
# HIERARCH ESO PRO REC1 CCD_ROT = 2.4
# HIERARCH ESO PRO REC1 CCD_SHIFT = 0.
# HIERARCH ESO PRO REC1 INIT_WLC = 'C       '
# HIERARCH ESO PRO REC1 ORDER_FIRST = 25
# HIERARCH ESO PRO REC1 ORDER_LAST = 63
# HIERARCH ESO PRO REC1 LINE_W = 5
# HIERARCH ESO PRO REC1 LINE_THRES = 1000.
# HIERARCH ESO PRO REC1 ID_ALPHA = 0.2
# HIERARCH ESO PRO REC1 ID_TOL = 0.2
# HIERARCH ESO PRO REC1 ID_THRES = 0.
# HIERARCH ESO PRO REC1 SPECTR_G = 79.
# HIERARCH ESO PRO REC1 SPECTR_F = 410.
# HIERARCH ESO PRO REC1 SPECTR_THB = 63.4
# HIERARCH ESO PRO REC1 REBIN_SCL = 'I       '
# HIERARCH ESO PRO REC1 REBIN_STEP = 0.03
# HIERARCH ESO PRO REC1 REBIN_MTD = 'S       '
# HIERARCH ESO PRO REC1 MERGE_OPT = 'YES     '
# HIERARCH ESO PRO REC1 MERGE_MTD = 'SINC    '
# HIERARCH ESO PRO REC1 MERGE_DELTA = 1.
# HIERARCH ESO PRO REC1 FF NAME = 'FF0702  '
# HIERARCH ESO PRO REC1 FF PRO CATG = 'MASTER_FLAT'
# HIERARCH ESO PRO REC1 FF PRO TYPE = 'PREPROCESSED'
# HIERARCH ESO PRO REC1 FF OBS NAME = 'Calibration' / OB name
# HIERARCH ESO PRO REC1 FF OBS START = '2013-08-11T10:43:49' / OB start time
# HIERARCH ESO PRO REC1 FF TPL NAME = 'FEROS FlatField' / Template name
# HIERARCH ESO PRO REC1 FF TPL START = '2013-08-11T10:47:53' / TPL start time
# HIERARCH ESO PRO REC1 FF RAW1 NAME = 'FEROS.2013-08-11T10:53:27.127.fits'
# HIERARCH ESO PRO REC1 FF RAW1 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW1 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW1 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW2 NAME = 'FEROS.2013-08-11T10:54:32.113.fits'
# HIERARCH ESO PRO REC1 FF RAW2 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW2 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW2 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW3 NAME = 'FEROS.2013-08-11T10:55:34.260.fits'
# HIERARCH ESO PRO REC1 FF RAW3 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW3 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW3 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW4 NAME = 'FEROS.2013-08-11T10:56:38.787.fits'
# HIERARCH ESO PRO REC1 FF RAW4 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW4 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW4 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW5 NAME = 'FEROS.2013-08-11T10:57:41.293.fits'
# HIERARCH ESO PRO REC1 FF RAW5 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW5 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW5 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW6 NAME = 'FEROS.2013-08-11T10:58:45.770.fits'
# HIERARCH ESO PRO REC1 FF RAW6 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW6 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW6 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW7 NAME = 'FEROS.2013-08-11T10:59:48.647.fits'
# HIERARCH ESO PRO REC1 FF RAW7 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW7 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW7 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW8 NAME = 'FEROS.2013-08-11T11:00:53.843.fits'
# HIERARCH ESO PRO REC1 FF RAW8 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW8 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW8 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW9 NAME = 'FEROS.2013-08-11T11:01:56.330.fits'
# HIERARCH ESO PRO REC1 FF RAW9 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW9 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW9 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW10 NAME = 'FEROS.2013-08-11T11:03:00.787.fits'
# HIERARCH ESO PRO REC1 FF RAW10 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW10 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW10 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 WLC NAME = 'ThArNe0718'
# HIERARCH ESO PRO REC1 WLC PRO CATG = 'MASTER_WAVE'
# HIERARCH ESO PRO REC1 WLC PRO TYPE = 'PREPROCESSED'
# HIERARCH ESO PRO REC1 WLC OBS NAME = 'Calibration' / OB name
# HIERARCH ESO PRO REC1 WLC OBS START = '2013-08-11T10:43:49' / OB start time
# HIERARCH ESO PRO REC1 WLC TPL NAME = 'FEROS wavelength calibration' / Templa
# HIERARCH ESO PRO REC1 WLC TPL START = '2013-08-11T11:12:19' / TPL start time
# HIERARCH ESO PRO REC1 WLC QC FIB1 NLINALL = 915
# HIERARCH ESO PRO REC1 WLC QC FIB1 NLINSEL = 912
# HIERARCH ESO PRO REC1 WLC QC FIB1 LINE RESIDMIN = -0.0204283
# HIERARCH ESO PRO REC1 WLC QC FIB1 LINE RESIDMAX = 0.0431138
# HIERARCH ESO PRO REC1 WLC QC FIB1 LINE RESIDAVG = -0.000122755
# HIERARCH ESO PRO REC1 WLC QC FIB1 LINE RESIDRMS = 0.00376192
# HIERARCH ESO PRO REC1 WLC QC FIB2 NLINALL = 968
# HIERARCH ESO PRO REC1 WLC QC FIB2 NLINSEL = 966
# HIERARCH ESO PRO REC1 WLC QC FIB2 LINE RESIDMIN = -0.0446334
# HIERARCH ESO PRO REC1 WLC QC FIB2 LINE RESIDMAX = 0.0296021
# HIERARCH ESO PRO REC1 WLC QC FIB2 LINE RESIDAVG = -0.000112406
# HIERARCH ESO PRO REC1 WLC QC FIB2 LINE RESIDRMS = 0.00597596
# HIERARCH ESO PRO REC1 WLC RAW1 NAME = 'FEROS.2013-08-11T11:13:43.634.fits'
# HIERARCH ESO PRO REC1 WLC RAW1 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 WLC RAW1 TYPE = 'WAVE    ' / Observation type
# HIERARCH ESO PRO REC1 WLC RAW1 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 WLC RAW2 NAME = 'FEROS.2013-08-11T11:14:53.802.fits'
# HIERARCH ESO PRO REC1 WLC RAW2 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 WLC RAW2 TYPE = 'WAVE    ' / Observation type
# HIERARCH ESO PRO REC1 WLC RAW2 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 WLC RAW3 NAME = 'FEROS.2013-08-11T11:16:10.499.fits'
# HIERARCH ESO PRO REC1 WLC RAW3 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 WLC RAW3 TYPE = 'WAVE    ' / Observation type
# HIERARCH ESO PRO REC1 WLC RAW3 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 WLC RAW4 NAME = 'FEROS.2013-08-11T11:18:16.292.fits'
# HIERARCH ESO PRO REC1 WLC RAW4 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 WLC RAW4 TYPE = 'WAVE    ' / Observation type
# HIERARCH ESO PRO REC1 WLC RAW4 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 WLC RAW5 NAME = 'FEROS.2013-08-11T11:20:29.086.fits'
# HIERARCH ESO PRO REC1 WLC RAW5 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 WLC RAW5 TYPE = 'WAVE    ' / Observation type
# HIERARCH ESO PRO REC1 WLC RAW5 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 WLC RAW6 NAME = 'FEROS.2013-08-11T11:23:52.147.fits'
# HIERARCH ESO PRO REC1 WLC RAW6 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 WLC RAW6 TYPE = 'WAVE    ' / Observation type
# HIERARCH ESO PRO REC1 WLC RAW6 TECH = 'ECHELLE ' / Observation technique
# M_EPOCH =                    F / True if resulting from multiple epochs
# SINGLEXP=                    T / True is resulting from single exposure
# NCOMBINE=                    1 / No of combined raw science files
# FLUXCAL = 'UNCALIBRATED'       / Type of flux calibration
# SPEC_RES=              48000.0 / Resolving power
# REFERENC= '        '           / Bibliographic reference
# PROCSOFT= 'FERN_DRS_1.0'       / Data reduction software
# PRODCATG= 'SCIENCE.SPECTRUM'   / Data product category
# PRODLVL =                    2 / Phase 3 product level
# SPECSYS = 'BARYCENT'           / Reference frame
# EXT_OBJ =                    F / True if extended
# CONTNORM=                    F / True if normalised to continuum
# TOT_FLUX=                    F / True if photometric
# FLUXERR =                 -1.0 / Unknown flux scale uncertainty
# DISPELEM= 'FEROS ECHELLE'      / Dispersive element name
# OBSTECH = 'ECHELLE '           / Observation technique
# ASSOC1  = 'ANCILLARY.FEROSTAR' / Associated files 1 category
# TEXPTIME=            1800.0055 / [s] Total integration time of all exposures
# PROG_ID = '091.D-0414(B)'      / ESO Programme ID
# OBID1   =            100340951 / Obs block ID
# MJD-END =       56515.32131369 / [d] End of observation
# DATE-END= '2013-08-11T07:42:41.503' / End of observation
# WAVELMIN=       352.7519999966 / [nm] Min wavelength
# WAVELMAX=       921.6689872804 / [nm] Max wavelength
# SPEC_BIN=               0.0030 / [nm] Wavelength bin size
# SNR     =                 11.6 / Median signal to noise (DER_SNR method)
# PROV1   = 'FEROS.2013-08-11T07:12:41.496.fits' / Originating file name
# ASSON1  = 'FEROS.2013-08-11T07:12:41.496_DRS_FERN_1.0.tgz' / Associated file 1 n
# ASSOM1  = 'd27f3bd006d000de598bad92fe03986b' / Associated file 1 md5sum
# DATE    = '2016-09-26T20:04:34.000' / Date this file was written
# ARCFILE = 'ADP.2016-09-27T09:50:45.369.fits' / Archive File Name
# ORIGFILE= 'FEROS.2013-08-11T07:12:41.496_DRS_FERN_1.0_ESOSDP.fits' / Original Fi
# P3ORIG  = 'IDP     '           / ESO internal data product
# HDRVER  = '2016-09-27T16:35:17.658' / ESO Archive header timetag
# COMMENT processed by hotfly version 2.1 on 2025-09-01T15:01:20.906 UT

# %%
#fits.getheader(Aug2005)

# %%
data1=fits.getdata(Aug2005)
data2=fits.getdata(Sept2005)
data3=fits.getdata(Aug2013)
data3
# Out:
# FITS_rec([([3527.51999997, 3527.54999997, 3527.57999997, ..., 9216.6298728 , 9216.6598728 , 9216.6898728 ], [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,  7.94802152e-04,  9.79057746e-04,  1.13056763e-03], [nan, nan, nan, ..., nan, nan, nan])],
#          dtype=(numpy.record, [('WAVE', '>f8', (189640,)), ('FLUX', '>f4', (189640,)), ('ERR', '>f4', (189640,))]))

# %%
#Data October 2015
xd1_new=data1['FLUX'][0][1000:-1000].tolist()
xd1_filt=median_filter(xd1_new,80)
lam1 = data1['WAVE'][0][1000:-1000]

mask_alpha1=np.abs(6562.8-lam1)>40
mask_beta1=np.abs(4861.33333333333-lam1)>40
mask_gamma1=np.abs(4367.23-lam1)>50 #H_gamma está corrido
mask1=mask_alpha1&mask_beta1&mask_gamma1

#Data December 2015
xd2_new=data2['FLUX'][0][1000:-1000].tolist()
xd2_filt=median_filter(xd2_new,80)
lam2 = data2['WAVE'][0][1000:-1000]

mask_alpha2=np.abs(6562.8-lam2)>40
mask_beta2=np.abs(4861.33333333333-lam2)>40
mask_gamma2=np.abs(4367.23-lam2)>50 #H_gamma está corrido
mask2=mask_alpha2&mask_beta2&mask_gamma2

#Data July 2016
xd3_new=data3['FLUX'][0][1000:-1000].tolist()
xd3_filt=median_filter(xd3_new,80)
lam3 = data3['WAVE'][0][1000:-1000]

mask_alpha3=np.abs(6562.8-lam3)>40
mask_beta3=np.abs(4861.33333333333-lam3)>40
mask_gamma3=np.abs(4367.23-lam3)>50 #H_gamma está corrido
mask3=mask_alpha3&mask_beta3&mask_gamma3

# %%
modelo1 = fitter(models.Chebyshev1D(25),lam1[mask1],xd1_filt[mask1])
modelo2 = fitter(models.Chebyshev1D(25),lam2[mask2],xd2_filt[mask2])
modelo3 = fitter(models.Chebyshev1D(25),lam3[mask3],xd3_filt[mask3])

# %%
fig, axs = plt.subplots(3, 1, sharex=True, figsize=(9, 7))  # 5 rows, 1 column

# Plot each light curve
axs[0].scatter(lam1-3.6,xd1_filt/modelo1(lam1),s=0.1, color='black', label='FEROS Agosto 2005')
axs[1].scatter(lam2-3.6,xd2_filt/modelo2(lam2), s=0.1, color='black',label='FEROS Septiembre 2005')
axs[2].scatter(lam3-3.6,xd3_filt/modelo3(lam3), s=0.1, color='black',label='FEROS Agosto 2013')



# Labels
for ax in axs:
    ax.set_ylabel('Intensidad',fontsize=14) 
    ax.axvline(x=6562.8, color='blue', linestyle='--', linewidth=1,label=r'H-$\alpha$')
    ax.axvline(x=6634.3, color='red', linestyle='--', linewidth=1)
    ax.axvline(x=4861.3, color='blue', linestyle='--', linewidth=1)

    ax.legend(loc='upper left', fontsize=12)
    ax.grid(True)
axs[-1].set_xlabel(r'Longitud de Onda [$\AA$]',fontsize=14)
axs[-1].set_xlim(6440, 6680)
#axs[-1].set_xlim(4740, 4980)#H-beta

axs[0].set_ylim(0, 2.5)
axs[1].set_ylim(0, 2.5)
axs[2].set_ylim(0,2.5)

fig.suptitle('Type 4 OGLE J004942.75-731717.7',fontsize=14)
plt.tight_layout()
plt.savefig('B049')
plt.show()

# %%
wb= 10 #Ancho banda azul
cb= 6530 #Posición banda azul
cr= 6590 #Posición roja
wr= 10 #Ancho banda roja
wf= 30 #Ancho banda emisión
cf = 6562.8 #Posición banda emisión
n_iter = 100

# %%
EW_sst = []
#with fits.open(Oct2015) as hdul:
#h1 = fits.getheader(UVES2001)                            
fl = (xd1_filt/modelo1(lam1))#[36200:-132000] #Flux normalizado
#efl = data1['ERR'][0]
wl = (lam1-3.5)#[36200:-132000] #wavelength

plt.figure(figsize=(12,4))

plt.plot(wl, fl-0.02,color='green', label='FEROS Agosto 2005')
plt.plot((lam2-3.3)[99000:-86000],(xd2_filt/modelo2(lam2))[99000:-86000]-0.15,color='blue',label='FEROS Septiembre 2005')
plt.plot((lam3-3.5),(xd3_filt/modelo3(lam3))-0.12,color='red',label='FEROS Agosto 2013')
plt.fill_between([6562.9+0.35-1.4862876385884796/2,6562.9+0.35+1.4862876385884796/2], 0.76,1, color='green', alpha=0.3)
plt.fill_between([6562.75-1.1158499520537195/2,6562.75+1.1158499520537195/2], 1,1.95, color='blue', alpha=0.3)
plt.fill_between([6562.8-1.17806966309203/2,6562.8+1.17806966309203/2], 0.6,1, color='red', alpha=0.3)



plt.xlabel('Longitud de onda (Å)', fontsize=12)
plt.ylabel('Intensidad normalizada', fontsize=12)
plt.title('Evolución temporal Hα de OGLE J004942.75-731717.', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.xlim(6530,6600)
plt.ylim(0,3)
plt.savefig('B049Variabl')
plt.show

SampleEW = []

# %%
def EW (wl, fl, cf, wf, cb, wb, cr, wr, n_iter):
    
    ratc = (cf-cb)/(cr-cb) #Término denominador de la ecuación de Hernandez et al.
    EWs = []
    
    for n in range(n_iter):

        #Formar banda emisión
        whf = np.where([(wl>cf-wf/2) & (wl<cf+wf/2)])[1]
        yf = [gauss(i, np.sqrt(i)) for i in fl[whf]]
        #np.abs(i)

        #Formar banda azul
        whb = np.where([(wl> cb-wb/2) & (wl< cb+wb/2)])[1]
        yb = [gauss(i, np.sqrt(i)) for i in fl[whb]]

        #Formar banda roja
        whr = np.where([(wl> cr-wr/2) & (wl< cr+wr/2)])[1]
        yr = [gauss(i, np.sqrt(i)) for i in fl[whr]]

        if np.isnan(yf).any() or np.isnan(yb).any() or np.isnan(yr).any():
            continue
        
        else:
        
            Ff = np.mean(yf)
            Fb = np.mean(yb)
            Fr = np.mean(yr)

            EWi = - wf * (1 - (Ff / ( Fb + ratc*(Fr - Fb))))

        EWs.append(EWi)

    EW = np.mean(np.array(EWs)[~np.isnan(EWs)])
    sEW = np.std(np.array(EWs)[~np.isnan(EWs)])
    return EW,sEW

# %%
EWmeAg2005 = EW(wl, fl, cf, wf, cb, wb, cr, wr, n_iter)
EWmeAg2005
# Out:
# (-1.4862876385884796, 1.384911722830861)

# %%
EWmeSept2005 = EW((lam2-3.5), (xd2_filt/modelo2(lam2)), cf, wf, cb, wb, cr, wr, n_iter)
EWmeSept2005
# Out:
# (-1.1158499520537195, 1.3341145427665841)

# %%
EWmeAg2013 = EW((lam3-3.5), (xd3_filt/modelo3(lam3)), cf, wf, cb, wb, cr, wr, n_iter)
EWmeAg2013
# Out:
# (-1.17806966309203, 1.3582074018342778)

# %%
fig, axs = plt.subplots(3, 1, sharex=True, figsize=(9, 7))  # 5 rows, 1 column

# Plot each light curve
axs[0].scatter(lam1-3.6,xd1_filt/modelo1(lam1),s=0.1, color='black', label='FEROS Agosto 2005')
axs[1].scatter(lam2-3.6,xd2_filt/modelo2(lam2), s=0.1, color='black',label='FEROS Septiembre 2005')
axs[2].scatter(lam3-3.6,xd3_filt/modelo3(lam3), s=0.1, color='black',label='FEROS Agosto 2013')



# Labels
for ax in axs:
    ax.set_ylabel('Intensidad',fontsize=14) 
    ax.axvline(x=6562.8, color='blue', linestyle='-', linewidth=1,label=r'Hydrogen')
    ax.axvline(x=4861.3, color='blue', linestyle='-', linewidth=1)
    ax.axvline(x=7155, color='gray', linestyle='--', linewidth=1,label=r'Iron II')
    ax.axvline(x=4244, color='gray', linestyle='--', linewidth=1)
    ax.axvline(x=4287, color='gray', linestyle='--', linewidth=1)
    ax.axvline(x=4415, color='gray', linestyle='--', linewidth=1)
    ax.axvline(x=5273, color='gray', linestyle='--', linewidth=1)
    ax.axvline(x=6300, color='darkred', linestyle='--', linewidth=1,label=r'Oxygen I')
    ax.axvline(x=6363, color='darkred', linestyle='--', linewidth=1)
    ax.axvline(x=5755, color='purple', linestyle='--', linewidth=1,label=r'Nytrogen II')
    ax.axvline(x=6584, color='purple', linestyle='--', linewidth=1)
    ax.axvline(x=4068, color='darkgreen', linestyle='--', linewidth=1,label=r'Sulfur II')
    ax.axvline(x=6717, color='darkgreen', linestyle='--', linewidth=1)
    ax.axvline(x=6730, color='darkgreen', linestyle='--', linewidth=1)
    ax.legend(loc='upper left', fontsize=12,ncol=3)
    ax.grid(True)
axs[-1].set_xlabel(r'Longitud de Onda [$\AA$]',fontsize=14)
axs[-1].set_xlim(4500, 7500)
axs[0].set_ylim(-3, 10)
axs[1].set_ylim(-3, 10)
axs[2].set_ylim(-3,10)

fig.suptitle('Type 4 OGLE J004942.75-731717.7',fontsize=14)
plt.tight_layout()
plt.savefig('B049_full')
plt.show()
